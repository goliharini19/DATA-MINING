# %% [markdown]
# <a href="https://colab.research.google.com/github/goliharini19/DATA-MINING/blob/main/Lab(DM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Add noise to the data
# Assuming X is defined previously and represents the input features

# Define y_true based on a linear relationship with X (example)
# Replace with your actual relationship if different
y_true = 2 * X + 1

# Define noise
noise = np.random.normal(0, 5, X.shape[0])  # Adjust noise level to see impact

# Calculate noisy observations
y = y_true + noise  # Noisy observations

# %%
# Fit a simple linear regression model
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# %%
# Plot the data
plt.scatter(X[:, 0], y[:, 0], label='Noisy Data')  # Use the first column of X for x-coordinates and the first column of y for y-coordinates
plt.plot(X[:, 0], y_true[:, 0], label='True Relationship', linestyle='dashed', color='green') # Use the first column of y_true for y-coordinates
plt.plot(X[:, 0], y_pred[:, 0], label='Regression Line', color='red') # Use the first column of y_pred for y-coordinates
plt.legend()
plt.xlabel('X')
plt.ylabel('y')
plt.title('Simple Linear Regression')
plt.show()
